# %% [markdown]
# ## LHb indrop analysis

# %%
#installed Seurat v2.0, on 8/1/2017

library(devtools)
library(dplyr)
library(useful)
library(ggplot2)
#install_github("satijalab/seurat")
library(Seurat)
library(stringr)
# Out:
# Warning message:
# "package 'devtools' was built under R version 3.3.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# "package 'useful' was built under R version 3.3.3"Loading required package: ggplot2
# Warning message:
# "package 'ggplot2' was built under R version 3.3.3"Loading required package: cowplot
#
# Attaching package: 'cowplot'
#
# The following object is masked from 'package:ggplot2':
#
#     ggsave
#
# Warning message:
# "package 'stringr' was built under R version 3.3.3"

# %%
setwd("Z:/Mike/drop_seq/LHb")

# %%
load("Tac2subclustering_14dim_1.2res.Robj") # Robj called Tac2

# %%
Tac2 <- UpdateSeuratObject(Tac2)

# %%
TSNEPlot(Tac2, do.label = T, pt.size = 3) # all Tac2 negative clusters from neuronal dataset
#VlnPlot(lhb,c('Syt6'), use.raw = F, y.log = F)
# Out:
# plot without title

# %%
JoyPlot(object = lhb, c('Slc6a1'), nCol = 2)
# Out:
# Picking joint bandwidth of 0.136
# plot without title

# %%
VlnPlot(Tac2, c("nGene", "nUMI", "percent.mito"), nCol = 3)
# Out:
# plot without title

# %%
VlnPlot(Tac2, c("Tac1", "Tac2",'Necab1', 'Slc17a7','Oprk1'), use.raw = F, y.log = F)
# Out:
# plot without title

# %% [markdown]
# # c2,4,8 are mHb, c3 &6 are PVthalmus

# %%
lhb = SubsetData(Tac2, ident.use = c('0','1','5','7')) # confirmed LHb clusters

# %%
VlnPlot(lhb, c("nGene", "nUMI", "percent.mito"), use.raw = F, y.log = F)
# Out:
# plot without title

# %%
TSNEPlot(lhb, do.label = T, pt.size = 3)
# Out:
# plot without title

# %%
features.plot <- c('Slc6a1','Chrm3', 'Sst','Vgf','Penk','Gpr151','Cartpt','Htr2c','Pcdh10')
DotPlot(object = lhb, genes.plot = features.plot, plot.legend = TRUE)
# Out:
# plot without title

# %%
VlnPlot(lhb,c('Slc6a1','Chrm3', 'Sst','Vgf','Penk','Gpr151','Cartpt','Htr2c','Pcdh10' ), use.raw = F, y.log = F)
# Out:
# plot without title

# %% [markdown]
# ## begin to subset data and looks at different clusters

# %%
c0 = SubsetData(Tac2, ident.use = c('0')) # subset with C0 only

# %%
GenePlot(c0,'Sst','Gpr151')
# Out:
# Plot with title "-0.02"

# %% [markdown]
# #subset of cells that are Gpr151+ and Sst-

# %%
FeaturePlot(object = lhb, features.plot = c("Gpr151", "Sst"), cols.use = c("grey", 
    "red", "blue", "green"), overlay = TRUE, no.legend = FALSE)
# Out:
# plot without title

# %%
GenePlot(c0,'Sst','Cartpt')
# Out:
# Plot with title "0.36"

# %% [markdown]
# #most CArtpt+ cells are Sst+

# %%
FeaturePlot(object = lhb, features.plot = c("Cartpt", "Sst"), cols.use = c("grey", 
    "red", "blue", "green"), overlay = TRUE, no.legend = FALSE)
# Out:
# plot without title

# %%
GenePlot(c0,'Gpr151','Htr2c')
# Out:
# Plot with title "-0.1"

# %%
FeaturePlot(object = lhb, features.plot = c("Gpr151", "Htr2c"), cols.use = c("grey", 
    "red", "blue", "green"), overlay = TRUE, no.legend = FALSE)
# Out:
# plot without title

# %% [markdown]
# ## C1

# %%
c1 = SubsetData(Tac2, ident.use = c('1')) # subset with C1 only

# %%
GenePlot(c1,'Slc6a1','Chrm3')
# Out:
# Plot with title "0.09"

# %% [markdown]
# # most C1 cells do not express both Chrm3 and Slc6a1

# %%
FeaturePlot(object = lhb, features.plot = c("Chrm3", "Slc6a1"), cols.use = c("grey", 
    "red", "blue", "green"), overlay = TRUE, no.legend = FALSE)
# Out:
# plot without title

# %%
FeaturePlot(object = lhb, features.plot = c("Chrm3", "Hpca"), cols.use = c("grey", 
    "red", "blue", "green"), overlay = TRUE, no.legend = FALSE)
# Out:
# plot without title
